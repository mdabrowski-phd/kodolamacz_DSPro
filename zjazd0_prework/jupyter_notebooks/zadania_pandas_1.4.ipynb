# %% [markdown]
# Zaimportuj bibliotekę pandas (użyj aliasu pd). Wczytaj dane dotyczące działań marketingowych banku - plik bank.csv. Dane pochodzą ze strony: https://archive.ics.uci.edu/ml/datasets/bank+marketing. Użyj instrukcji:
#
#
# data = pd.read_csv("ścieżka_do_pliku_bank.csv", sep=";")

# %%
import pandas as pd

# %% [markdown]
# a) Sprawdź jaki rezultat dałoby wczytanie danych używając tylko pd.read_csv("ścieżka_do_pliku_bank.csv")

# %%
data = pd.read_csv("./bank/bank.csv", sep=";")
# data = pd.read_csv("./bank/bank.csv")

# %% [markdown]
# b) Wyświetl 5 pierwszych wierszy na dwa sposoby: używając metody head() na ramce danych oraz korzystając z iloc. Wyświetl przy użyciu metody head 10 pierwszych wierszy (jeśli nie wiesz jak to zrobić (zajrzyj do dokumentacji funkcji head odpalając kod data.head?).

# %%
data.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
data.iloc[:5]
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
data.head?
data.head(10)
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   30     unemployed  married    primary      no     1787      no   no
# 1   33       services  married  secondary      no     4789     yes  yes
# 2   35     management   single   tertiary      no     1350     yes   no
# 3   30     management  married   tertiary      no     1476     yes  yes
# 4   59    blue-collar  married  secondary      no        0     yes   no
# 5   35     management   single   tertiary      no      747      no   no
# 6   36  self-employed  married   tertiary      no      307     yes   no
# 7   39     technician  married  secondary      no      147     yes   no
# 8   41   entrepreneur  married   tertiary      no      221     yes   no
# 9   43       services  married    primary      no      -88     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# ...

# %% [markdown]
# c) Wypisz statystyki kolumn liczbowych używając metody describe. Zwróć wiersz zawierający wartości kwartyla rzędu 25% na dwa sposoby: używając iloc i numeru wiersza oraz używają loc i nazwy wiersza.

# %%
data.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
data.describe().iloc[4]
# Out:
# age          33.0
# balance      69.0
# day           9.0
# duration    104.0
# campaign      1.0
# pdays        -1.0
# previous      0.0
# Name: 25%, dtype: float64

# %%
data.describe().loc["25%"]
# Out:
# age          33.0
# balance      69.0
# day           9.0
# duration    104.0
# campaign      1.0
# pdays        -1.0
# previous      0.0
# Name: 25%, dtype: float64

# %% [markdown]
# d) Zwróć te osoby (wiersze tabeli), z którymi bank kontaktował się w  poprzedniej kampani marketingowej (previous jest dodatnie).

# %%
data[data["previous"] > 0]
# Out:
#       age            job  marital  education default  balance housing loan  \
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 5      35     management   single   tertiary      no      747      no   no
# 6      36  self-employed  married   tertiary      no      307     yes   no
# 9      43       services  married    primary      no      -88     yes  yes
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4492   32     technician   single  secondary      no      309     yes  yes
# 4504   42    blue-collar   single  secondary      no     1080     yes  yes
# 4514   38    blue-collar  married  secondary      no     1205     yes   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# e) Zwróć te osoby, z którymi bank kontaktował się w poniedziałek (zmienna day_of_week, wartość “mon”).

# %%
data[data.day == 1]
# Out:
#       age           job   marital  education default  balance housing loan  \
# 95     41       unknown    single   tertiary      no     1567      no   no
# 152    45    unemployed  divorced    primary     yes     -249     yes  yes
# 156    55        admin.   married  secondary      no      602      no   no
# 301    65       retired  divorced    primary      no     1840      no   no
# 444    62       retired   married  secondary      no      816      no   no
# 462    45    management  divorced   tertiary      no        0      no   no
# 662    38    technician    single   tertiary      no       25     yes   no
# 684    28      services    single  secondary      no      168      no   no
# 756    48    management   married   tertiary      no     1167     yes  yes
# 944    40   blue-collar   married  secondary      no     1451      no   no
# 1005   41    management   married   tertiary      no    10758     yes   no
# ...

# %% [markdown]
# f) Oblicz ile osób jest w wieku (zmienna age) powyżej 70 lat.

# %%
np.sum(data.age > 70)
# Out:
# 54

# %% [markdown]
# g) Oblicz ile procent osób, z którym bank kontaktował się w poniedziałek, skorzystało z oferty (zmienna y równa “yes”). Wskazówka: procent jedynek z kolumny binarnej (o wartościach 0 i 1) to to samo co średnia z tej kolumny.

# %%
np.mean(data[data.month == "may"].y == "yes")
# Out:
# 0.06652360515021459

# %% [markdown]
# h) Zwróć liczebności występowania poszczególnych zawodów w danych (zmienna job).

# %%
data.groupby("job").age.count()
# Out:
# job
# admin.           478
# blue-collar      946
# entrepreneur     168
# housemaid        112
# management       969
# retired          230
# self-employed    183
# services         417
# student           84
# technician       768
# unemployed       128
# unknown           38
# Name: age, dtype: int64

# %% [markdown]
# i) Zwróć najliczniejszą kategorię wykształcenia osób w danych (zmienna education).

# %%
max_population = data.groupby("education").age.count()
print(max_population)
max_population.index[np.argmax(max_population)]
# Out:
# education
# primary       678
# secondary    2306
# tertiary     1350
# unknown       187
# Name: age, dtype: int64
# 'secondary'
